# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
import seaborn as sns

# plt.style.use('seaborn-whitegrid')
sns.set_style("whitegrid")
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# # Setup feedback system
# from learntools.core import binder
# binder.bind(globals())
# from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = X['arrival_date_month'].map(  {'January':1, 'February': 2, 'March':3,
                                                        'April':4, 'May':5, 'June':6, 'July':7,
                                                        'August':8, 'September':9, 'October':10,
                                                        'November':11, 'December':12})

features_num = ["lead_time", "arrival_date_week_number",
                "arrival_date_day_of_month", "stays_in_weekend_nights",
                "stays_in_week_nights", "adults", "children", "babies",
                "is_repeated_guest", "previous_cancellations",
                "previous_bookings_not_canceled", "required_car_parking_spaces",
                "total_of_special_requests", "adr",]

features_cat = ["hotel", "arrival_date_month", "meal",
                "market_segment", "distribution_channel",
                "reserved_room_type", "deposit_type", "customer_type",]

transformer_num = make_pipeline(SimpleImputer(strategy="constant"), # there are a few missing values
                                StandardScaler(),)

transformer_cat = make_pipeline(SimpleImputer(strategy="constant", fill_value="NA"),
                                OneHotEncoder(handle_unknown='ignore'),)

preprocessor = make_column_transformer( (transformer_num, features_num),
                                        (transformer_cat, features_cat),)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([  layers.BatchNormalization(input_shape=[X_train.shape[1]]),
                            layers.Dense(256, activation='relu'),
                            layers.BatchNormalization(),
                            layers.Dropout(0.3),
                            layers.Dense(256, activation='relu'),
                            layers.BatchNormalization(),
                            layers.Dropout(0.3),   
                            layers.Dense(1, activation='sigmoid'),])

# Check your answer
# q_1.check()

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(  optimizer='adam',
                loss='binary_crossentropy',
                metrics=['binary_accuracy'],)

# Check your answer
# q_2.check()

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping( patience=5,
                                                min_delta=0.001,
                                                restore_best_weights=True,)
history = model.fit(X_train, y_train,
                    validation_data=(X_valid, y_valid),
                    batch_size=512,
                    epochs=200,
                    callbacks=[early_stopping],)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 2s 8ms/step - loss: 0.4781 - binary_accuracy: 0.7733 - val_loss: 0.4396 - val_binary_accuracy: 0.8085
# Epoch 2/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4222 - binary_accuracy: 0.8016 - val_loss: 0.4035 - val_binary_accuracy: 0.8154
# Epoch 3/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4087 - binary_accuracy: 0.8090 - val_loss: 0.3962 - val_binary_accuracy: 0.8144
# Epoch 4/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4017 - binary_accuracy: 0.8124 - val_loss: 0.3903 - val_binary_accuracy: 0.8188
# Epoch 5/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3964 - binary_accuracy: 0.8157 - val_loss: 0.3893 - val_binary_accuracy: 0.8204
# Epoch 6/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3918 - binary_accuracy: 0.8179 - val_loss: 0.3840 - val_binary_accuracy: 0.8239
# Epoch 7/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3875 - binary_accuracy: 0.8200 - val_loss: 0.3809 - val_binary_accuracy: 0.8238
# Epoch 8/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3845 - binary_accuracy: 0.8209 - val_loss: 0.3782 - val_binary_accuracy: 0.8249
# Epoch 9/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3818 - binary_accuracy: 0.8226 - val_loss: 0.3753 - val_binary_accuracy: 0.8290
# Epoch 10/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3794 - binary_accuracy: 0.8250 - val_loss: 0.3724 - val_binary_accuracy: 0.8291
# Epoch 11/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3766 - binary_accuracy: 0.8257 - val_loss: 0.3755 - val_binary_accuracy: 0.8284
# Epoch 12/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3729 - binary_accuracy: 0.8278 - val_loss: 0.3687 - val_binary_accuracy: 0.8312
# Epoch 13/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3722 - binary_accuracy: 0.8276 - val_loss: 0.3682 - val_binary_accuracy: 0.8323
# Epoch 14/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3688 - binary_accuracy: 0.8284 - val_loss: 0.3657 - val_binary_accuracy: 0.8321
# Epoch 15/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3664 - binary_accuracy: 0.8307 - val_loss: 0.3754 - val_binary_accuracy: 0.8279
# Epoch 16/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3661 - binary_accuracy: 0.8307 - val_loss: 0.3627 - val_binary_accuracy: 0.8341
# Epoch 17/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3641 - binary_accuracy: 0.8320 - val_loss: 0.3649 - val_binary_accuracy: 0.8334
# Epoch 18/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3619 - binary_accuracy: 0.8328 - val_loss: 0.3641 - val_binary_accuracy: 0.8328
# Epoch 19/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3615 - binary_accuracy: 0.8329 - val_loss: 0.3605 - val_binary_accuracy: 0.8360
# Epoch 20/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3592 - binary_accuracy: 0.8344 - val_loss: 0.3581 - val_binary_accuracy: 0.8360
# Epoch 21/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3577 - binary_accuracy: 0.8359 - val_loss: 0.3600 - val_binary_accuracy: 0.8354
# Epoch 22/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3559 - binary_accuracy: 0.8353 - val_loss: 0.3596 - val_binary_accuracy: 0.8349
# Epoch 23/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3544 - binary_accuracy: 0.8351 - val_loss: 0.3570 - val_binary_accuracy: 0.8374
# Epoch 24/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3538 - binary_accuracy: 0.8368 - val_loss: 0.3589 - val_binary_accuracy: 0.8374
# Epoch 25/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3519 - binary_accuracy: 0.8372 - val_loss: 0.3582 - val_binary_accuracy: 0.8361
# Epoch 26/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3521 - binary_accuracy: 0.8381 - val_loss: 0.3554 - val_binary_accuracy: 0.8371
# Epoch 27/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3510 - binary_accuracy: 0.8377 - val_loss: 0.3543 - val_binary_accuracy: 0.8389
# Epoch 28/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3489 - binary_accuracy: 0.8380 - val_loss: 0.3546 - val_binary_accuracy: 0.8378
# Epoch 29/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3477 - binary_accuracy: 0.8391 - val_loss: 0.3564 - val_binary_accuracy: 0.8376
# Epoch 30/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3469 - binary_accuracy: 0.8397 - val_loss: 0.3555 - val_binary_accuracy: 0.8375
# Epoch 31/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3452 - binary_accuracy: 0.8402 - val_loss: 0.3546 - val_binary_accuracy: 0.8397
# Epoch 32/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3467 - binary_accuracy: 0.8397 - val_loss: 0.3520 - val_binary_accuracy: 0.8394
# Epoch 33/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3449 - binary_accuracy: 0.8410 - val_loss: 0.3516 - val_binary_accuracy: 0.8392
# Epoch 34/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3437 - binary_accuracy: 0.8410 - val_loss: 0.3525 - val_binary_accuracy: 0.8388
# Epoch 35/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3423 - binary_accuracy: 0.8409 - val_loss: 0.3517 - val_binary_accuracy: 0.8393
# Epoch 36/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3413 - binary_accuracy: 0.8426 - val_loss: 0.3516 - val_binary_accuracy: 0.8382
# Epoch 37/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3400 - binary_accuracy: 0.8427 - val_loss: 0.3490 - val_binary_accuracy: 0.8406
# Epoch 38/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3398 - binary_accuracy: 0.8430 - val_loss: 0.3515 - val_binary_accuracy: 0.8395
# Epoch 39/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3388 - binary_accuracy: 0.8430 - val_loss: 0.3497 - val_binary_accuracy: 0.8410
# Epoch 40/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3371 - binary_accuracy: 0.8442 - val_loss: 0.3505 - val_binary_accuracy: 0.8410
# Epoch 41/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3384 - binary_accuracy: 0.8449 - val_loss: 0.3484 - val_binary_accuracy: 0.8401
# Epoch 42/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3378 - binary_accuracy: 0.8430 - val_loss: 0.3494 - val_binary_accuracy: 0.8410
# <AxesSubplot: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
# q_3.check()

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
